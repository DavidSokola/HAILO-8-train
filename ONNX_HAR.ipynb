# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /local/workspace/doc

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /local/workspace/doc

# %%
cd ..
# Out:
# /local/workspace

# %%
import os

# Define the directory path
directory = "/local/workspace/"

# List the contents of the directory
try:
    files = os.listdir(directory)
    print(f"Contents of '{directory}':")
    for f in files:
        print(f)
except Exception as e:
    print(f"Error reading directory '{directory}': {e}")
# Out:
# Contents of '/local/workspace/':
# tappas
# hailort_examples
# hailo_model_zoo
# hailo_virtualenv
# best.onnx
# doc

# %%
import os

# Set the directory and target filename
directory = "/local/workspace/"
target_file = "best.onnx"
full_path = os.path.join(directory, target_file)

# List the contents of the directory
print(f"Contents of '{directory}':")
files = os.listdir(directory)
for file in files:
    print(file)

# Check if 'best.onnx' exists
if target_file in files:
    print(f"\nFound '{target_file}' in {directory}.")
    print("Full path:", full_path)
    # Optionally, display additional information such as file size
    file_size = os.path.getsize(full_path)
    print(f"File size: {file_size} bytes")
else:
    print(f"\n'{target_file}' not found in {directory}.")
# Out:
# Contents of '/local/workspace/':
# tappas
# hailort_examples
# hailo_model_zoo
# hailo_virtualenv
# best.onnx
# doc
#
# Found 'best.onnx' in /local/workspace/.
# Full path: /local/workspace/best.onnx
# File size: 7505993 bytes

# %%
import onnx

# Load the ONNX model
model_path = "/local/workspace/best.onnx"  # Replace with your model's path
model = onnx.load(model_path)

# Extract and display the output node names
print("Output Node Names:")
for output in model.graph.output:
    print(output.name)

# Extract and display the input node names
print("\nInput Node Names:")
for input_node in model.graph.input:
    print(input_node.name)

# Extract and display all node names
print("\nAll Node Names:")
for node in model.graph.node:
    print(node.name)
# Out:
# Output Node Names:
# output0
#
# Input Node Names:
# images
#
# All Node Names:
# /model.0/conv/Conv
# /model.0/act/Sigmoid
# /model.0/act/Mul
# /model.1/conv/Conv
# /model.1/act/Sigmoid
# /model.1/act/Mul
# /model.2/cv1/conv/Conv
# /model.2/cv1/act/Sigmoid
# /model.2/cv1/act/Mul
# /model.2/m/m.0/cv1/conv/Conv
# /model.2/m/m.0/cv1/act/Sigmoid
# /model.2/m/m.0/cv1/act/Mul
# /model.2/m/m.0/cv2/conv/Conv
# /model.2/m/m.0/cv2/act/Sigmoid
# /model.2/m/m.0/cv2/act/Mul
# /model.2/m/m.0/Add
# /model.2/cv2/conv/Conv
# /model.2/cv2/act/Sigmoid
# /model.2/cv2/act/Mul
# /model.2/Concat
# /model.2/cv3/conv/Conv
# /model.2/cv3/act/Sigmoid
# /model.2/cv3/act/Mul
# /model.3/conv/Conv
# /model.3/act/Sigmoid
# /model.3/act/Mul
# /model.4/cv1/conv/Conv
# /model.4/cv1/act/Sigmoid
# /model.4/cv1/act/Mul
# /model.4/m/m.0/cv1/conv/Conv
# /model.4/m/m.0/cv1/act/Sigmoid
# /model.4/m/m.0/cv1/act/Mul
# /model.4/m/m.0/cv2/conv/Conv
# /model.4/m/m.0/cv2/act/Sigmoid
# /model.4/m/m.0/cv2/act/Mul
# /model.4/m/m.0/Add
# /model.4/m/m.1/cv1/conv/Conv
# /model.4/m/m.1/cv1/act/Sigmoid
# /model.4/m/m.1/cv1/act/Mul
# /model.4/m/m.1/cv2/conv/Conv
# /model.4/m/m.1/cv2/act/Sigmoid
# /model.4/m/m.1/cv2/act/Mul
# /model.4/m/m.1/Add
# /model.4/cv2/conv/Conv
# /model.4/cv2/act/Sigmoid
# /model.4/cv2/act/Mul
# /model.4/Concat
# /model.4/cv3/conv/Conv
# /model.4/cv3/act/Sigmoid
# /model.4/cv3/act/Mul
# /model.5/conv/Conv
# /model.5/act/Sigmoid
# /model.5/act/Mul
# /model.6/cv1/conv/Conv
# /model.6/cv1/act/Sigmoid
# /model.6/cv1/act/Mul
# /model.6/m/m.0/cv1/conv/Conv
# /model.6/m/m.0/cv1/act/Sigmoid
# /model.6/m/m.0/cv1/act/Mul
# /model.6/m/m.0/cv2/conv/Conv
# /model.6/m/m.0/cv2/act/Sigmoid
# /model.6/m/m.0/cv2/act/Mul
# /model.6/m/m.0/Add
# /model.6/m/m.1/cv1/conv/Conv
# /model.6/m/m.1/cv1/act/Sigmoid
# /model.6/m/m.1/cv1/act/Mul
# /model.6/m/m.1/cv2/conv/Conv
# /model.6/m/m.1/cv2/act/Sigmoid
# /model.6/m/m.1/cv2/act/Mul
# /model.6/m/m.1/Add
# /model.6/m/m.2/cv1/conv/Conv
# /model.6/m/m.2/cv1/act/Sigmoid
# /model.6/m/m.2/cv1/act/Mul
# /model.6/m/m.2/cv2/conv/Conv
# /model.6/m/m.2/cv2/act/Sigmoid
# /model.6/m/m.2/cv2/act/Mul
# /model.6/m/m.2/Add
# /model.6/cv2/conv/Conv
# /model.6/cv2/act/Sigmoid
# /model.6/cv2/act/Mul
# /model.6/Concat
# /model.6/cv3/conv/Conv
# /model.6/cv3/act/Sigmoid
# /model.6/cv3/act/Mul
# /model.7/conv/Conv
# /model.7/act/Sigmoid
# /model.7/act/Mul
# /model.8/cv1/conv/Conv
# /model.8/cv1/act/Sigmoid
# /model.8/cv1/act/Mul
# /model.8/m/m.0/cv1/conv/Conv
# /model.8/m/m.0/cv1/act/Sigmoid
# /model.8/m/m.0/cv1/act/Mul
# /model.8/m/m.0/cv2/conv/Conv
# /model.8/m/m.0/cv2/act/Sigmoid
# /model.8/m/m.0/cv2/act/Mul
# /model.8/m/m.0/Add
# /model.8/cv2/conv/Conv
# /model.8/cv2/act/Sigmoid
# /model.8/cv2/act/Mul
# /model.8/Concat
# /model.8/cv3/conv/Conv
# /model.8/cv3/act/Sigmoid
# /model.8/cv3/act/Mul
# /model.9/cv1/conv/Conv
# /model.9/cv1/act/Sigmoid
# /model.9/cv1/act/Mul
# /model.9/m/MaxPool
# /model.9/m_1/MaxPool
# /model.9/m_2/MaxPool
# /model.9/Concat
# /model.9/cv2/conv/Conv
# /model.9/cv2/act/Sigmoid
# /model.9/cv2/act/Mul
# /model.10/conv/Conv
# /model.10/act/Sigmoid
# /model.10/act/Mul
# /model.11/Constant
# /model.11/Resize
# /model.12/Concat
# /model.13/cv1/conv/Conv
# /model.13/cv1/act/Sigmoid
# /model.13/cv1/act/Mul
# /model.13/m/m.0/cv1/conv/Conv
# /model.13/m/m.0/cv1/act/Sigmoid
# /model.13/m/m.0/cv1/act/Mul
# /model.13/m/m.0/cv2/conv/Conv
# /model.13/m/m.0/cv2/act/Sigmoid
# /model.13/m/m.0/cv2/act/Mul
# /model.13/cv2/conv/Conv
# /model.13/cv2/act/Sigmoid
# /model.13/cv2/act/Mul
# /model.13/Concat
# /model.13/cv3/conv/Conv
# /model.13/cv3/act/Sigmoid
# /model.13/cv3/act/Mul
# /model.14/conv/Conv
# /model.14/act/Sigmoid
# /model.14/act/Mul
# /model.15/Constant
# /model.15/Resize
# /model.16/Concat
# /model.17/cv1/conv/Conv
# /model.17/cv1/act/Sigmoid
# /model.17/cv1/act/Mul
# /model.17/m/m.0/cv1/conv/Conv
# /model.17/m/m.0/cv1/act/Sigmoid
# /model.17/m/m.0/cv1/act/Mul
# /model.17/m/m.0/cv2/conv/Conv
# /model.17/m/m.0/cv2/act/Sigmoid
# /model.17/m/m.0/cv2/act/Mul
# /model.17/cv2/conv/Conv
# /model.17/cv2/act/Sigmoid
# /model.17/cv2/act/Mul
# /model.17/Concat
# /model.17/cv3/conv/Conv
# /model.17/cv3/act/Sigmoid
# /model.17/cv3/act/Mul
# /model.18/conv/Conv
# /model.18/act/Sigmoid
# /model.18/act/Mul
# /model.19/Concat
# /model.20/cv1/conv/Conv
# /model.20/cv1/act/Sigmoid
# /model.20/cv1/act/Mul
# /model.20/m/m.0/cv1/conv/Conv
# /model.20/m/m.0/cv1/act/Sigmoid
# /model.20/m/m.0/cv1/act/Mul
# /model.20/m/m.0/cv2/conv/Conv
# /model.20/m/m.0/cv2/act/Sigmoid
# /model.20/m/m.0/cv2/act/Mul
# /model.20/cv2/conv/Conv
# /model.20/cv2/act/Sigmoid
# /model.20/cv2/act/Mul
# /model.20/Concat
# /model.20/cv3/conv/Conv
# /model.20/cv3/act/Sigmoid
# /model.20/cv3/act/Mul
# /model.21/conv/Conv
# /model.21/act/Sigmoid
# /model.21/act/Mul
# /model.22/Concat
# /model.23/cv1/conv/Conv
# /model.23/cv1/act/Sigmoid
# /model.23/cv1/act/Mul
# /model.23/m/m.0/cv1/conv/Conv
# /model.23/m/m.0/cv1/act/Sigmoid
# /model.23/m/m.0/cv1/act/Mul
# /model.23/m/m.0/cv2/conv/Conv
# /model.23/m/m.0/cv2/act/Sigmoid
# /model.23/m/m.0/cv2/act/Mul
# /model.23/cv2/conv/Conv
# /model.23/cv2/act/Sigmoid
# /model.23/cv2/act/Mul
# /model.23/Concat
# /model.23/cv3/conv/Conv
# /model.23/cv3/act/Sigmoid
# /model.23/cv3/act/Mul
# /model.24/m.0/Conv
# /model.24/Constant
# /model.24/Reshape
# /model.24/Transpose
# /model.24/Sigmoid
# Constant_230
# /model.24/Split
# /model.24/Constant_1
# /model.24/Mul
# /model.24/Constant_2
# /model.24/Add
# /model.24/Constant_3
# /model.24/Mul_1
# /model.24/Constant_4
# /model.24/Mul_2
# /model.24/Constant_5
# /model.24/Pow
# /model.24/Constant_6
# /model.24/Mul_3
# /model.24/Concat
# /model.24/Constant_7
# /model.24/Reshape_1
# /model.24/m.1/Conv
# /model.24/Constant_8
# /model.24/Reshape_2
# /model.24/Transpose_1
# /model.24/Sigmoid_1
# /model.24/Split_1
# /model.24/Constant_9
# /model.24/Mul_4
# /model.24/Constant_10
# /model.24/Add_1
# /model.24/Constant_11
# /model.24/Mul_5
# /model.24/Constant_12
# /model.24/Mul_6
# /model.24/Constant_13
# /model.24/Pow_1
# /model.24/Constant_14
# /model.24/Mul_7
# /model.24/Concat_1
# /model.24/Constant_15
# /model.24/Reshape_3
# /model.24/m.2/Conv
# /model.24/Constant_16
# /model.24/Reshape_4
# /model.24/Transpose_2
# /model.24/Sigmoid_2
# /model.24/Split_2
# /model.24/Constant_17
# /model.24/Mul_8
# /model.24/Constant_18
# /model.24/Add_2
# /model.24/Constant_19
# /model.24/Mul_9
# /model.24/Constant_20
# /model.24/Mul_10
# /model.24/Constant_21
# /model.24/Pow_2
# /model.24/Constant_22
# /model.24/Mul_11
# /model.24/Concat_2
# /model.24/Constant_23
# /model.24/Reshape_5
# /model.24/Concat_3

# %%
import os
from hailo_sdk_client import ClientRunner
from IPython.display import SVG

# Set the Hailo hardware architecture
chosen_hw_arch = "hailo8"  # Use 'hailo15h' for Hailo15 devices or 'hailo8r' for Mini PCIe modules.

# %%
onnx_model_name = "best_model"  # Name of your model
onnx_path = "/local/workspace/best.onnx"  # Adjust this path if needed

# %%
runner = ClientRunner(hw_arch=chosen_hw_arch)

# %%
# Recommended end node names
end_node_names = ["/model.24/Sigmoid_1", "/model.24/Sigmoid", "/model.24/Sigmoid_2"]

try:
    hn, npz = runner.translate_onnx_model(
        model=onnx_path,
        net_name=onnx_model_name,
        end_node_names=end_node_names,
        net_input_shapes={"images": [1, 3, 640, 640]}  # Adjust dimensions if needed
    )
    print("ONNX model successfully translated to Hailo format.")
except Exception as e:
    print(f"Error during ONNX translation: {e}")
# Out:
# [info] Translation started on ONNX model best_model
# [info] Restored ONNX model best_model (completion time: 00:00:00.02)
# [info] Extracted ONNXRuntime meta-data for Hailo model (completion time: 00:00:00.09)
# [info] NMS structure of yolov5 (or equivalent architecture) was detected.
# [info] Start nodes mapped from original model: 'images': 'best_model/input_layer1'.
# [info] End nodes mapped from original model: '/model.24/Sigmoid_1', '/model.24/Sigmoid', '/model.24/Sigmoid_2'.
# [info] Translation completed on ONNX model best_model (completion time: 00:00:00.61)
# ONNX model successfully translated to Hailo format.

# %%
# Save the model as a HAR file
hailo_model_har_name = "best_model_hailo.har"
runner.save_har(hailo_model_har_name)
print(f"Model saved as HAR file: {hailo_model_har_name}")
# Out:
# [info] Saved HAR to: /local/workspace/best_model_hailo.har
# Model saved as HAR file: best_model_hailo.har
